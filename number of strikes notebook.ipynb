# %%
# Import statements
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('strikes_data1.csv') 
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3401012 entries, 0 to 3401011
# Data columns (total 3 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   date               datetime64[ns]
#  1   number_of_strikes  int64
#  2   center_point_geom  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 77.8+ MB

# %%
df.head()
# Out:
#         date  number_of_strikes center_point_geom
# 0 2018-01-03                194     POINT(-75 27)
# 1 2018-01-03                 41   POINT(-78.4 29)
# 2 2018-01-03                 33   POINT(-73.9 27)
# 3 2018-01-03                 38   POINT(-73.8 27)
# 4 2018-01-03                 92     POINT(-79 28)

# %%
df.shape
# Out:
# (3401012, 3)

# %%
df.drop_duplicates().shape
# Out:
# (3401012, 3)

# %%
df.sort_values(by="number_of_strikes", ascending = False).head()
# Out:
#              date  number_of_strikes  center_point_geom
# 302758 2018-08-20               2211  POINT(-92.5 35.5)
# 278383 2018-08-16               2142  POINT(-96.1 36.1)
# 280830 2018-08-17               2061  POINT(-90.2 36.1)
# 280453 2018-08-17               2031  POINT(-89.9 35.9)
# 278382 2018-08-16               1902  POINT(-96.2 36.1)

# %%
df.center_point_geom.value_counts()[:20].rename_axis('unique_values').reset_index(name="counts").style.background_gradient()
# Out:
# <style type="text/css">
# #T_f96b6_row0_col1, #T_f96b6_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f96b6_row2_col1, #T_f96b6_row3_col1 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_f96b6_row4_col1, #T_f96b6_row5_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_f96b6_row6_col1, #T_f96b6_row7_col1 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_f96b6_row8_col1, #T_f96b6_row9_col1 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_f96b6_row10_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_f96b6_row11_col1, #T_f96b6_row12_col1, #T_f96b6_row13_col1, #T_f96b6_row14_col1, #T_f96b6_row15_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_f96b6_row16_col1, #T_f96b6_row17_col1, #T_f96b6_row18_col1, #T_f96b6_row19_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_f96b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f96b6_level0_col0" class="col_heading level0 col0" >unique_values</th>
#       <th id="T_f96b6_level0_col1" class="col_heading level0 col1" >counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f96b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f96b6_row0_col0" class="data row0 col0" >POINT(-81.5 22.5)</td>
#       <td id="T_f96b6_row0_col1" class="data row0 col1" >108</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f96b6_row1_col0" class="data row1 col0" >POINT(-84.1 22.4)</td>
#       <td id="T_f96b6_row1_col1" class="data row1 col1" >108</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f96b6_row2_col0" class="data row2 col0" >POINT(-82.5 22.9)</td>
#       <td id="T_f96b6_row2_col1" class="data row2 col1" >107</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f96b6_row3_col0" class="data row3 col0" >POINT(-82.7 22.9)</td>
#       <td id="T_f96b6_row3_col1" class="data row3 col1" >107</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f96b6_row4_col0" class="data row4 col0" >POINT(-82.5 22.8)</td>
#       <td id="T_f96b6_row4_col1" class="data row4 col1" >106</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f96b6_row5_col0" class="data row5 col0" >POINT(-84.2 22.3)</td>
#       <td id="T_f96b6_row5_col1" class="data row5 col1" >106</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f96b6_row6_col0" class="data row6 col0" >POINT(-76 20.5)</td>
#       <td id="T_f96b6_row6_col1" class="data row6 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f96b6_row7_col0" class="data row7 col0" >POINT(-75.9 20.4)</td>
#       <td id="T_f96b6_row7_col1" class="data row7 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f96b6_row8_col0" class="data row8 col0" >POINT(-82.2 22.9)</td>
#       <td id="T_f96b6_row8_col1" class="data row8 col1" >104</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f96b6_row9_col0" class="data row9 col0" >POINT(-78 18.2)</td>
#       <td id="T_f96b6_row9_col1" class="data row9 col1" >104</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f96b6_row10_col0" class="data row10 col0" >POINT(-83.9 22.5)</td>
#       <td id="T_f96b6_row10_col1" class="data row10 col1" >103</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f96b6_row11_col0" class="data row11 col0" >POINT(-84 22.4)</td>
#       <td id="T_f96b6_row11_col1" class="data row11 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f96b6_row12_col0" class="data row12 col0" >POINT(-82 22.8)</td>
#       <td id="T_f96b6_row12_col1" class="data row12 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f96b6_row13_col0" class="data row13 col0" >POINT(-82 22.4)</td>
#       <td id="T_f96b6_row13_col1" class="data row13 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f96b6_row14_col0" class="data row14 col0" >POINT(-82.3 22.9)</td>
#       <td id="T_f96b6_row14_col1" class="data row14 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f96b6_row15_col0" class="data row15 col0" >POINT(-78 18.3)</td>
#       <td id="T_f96b6_row15_col1" class="data row15 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f96b6_row16_col0" class="data row16 col0" >POINT(-84.1 22.5)</td>
#       <td id="T_f96b6_row16_col1" class="data row16 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f96b6_row17_col0" class="data row17 col0" >POINT(-75.5 20.6)</td>
#       <td id="T_f96b6_row17_col1" class="data row17 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f96b6_row18_col0" class="data row18 col0" >POINT(-84.2 22.4)</td>
#       <td id="T_f96b6_row18_col1" class="data row18 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_f96b6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f96b6_row19_col0" class="data row19 col0" >POINT(-76 20.4)</td>
#       <td id="T_f96b6_row19_col1" class="data row19 col1" >101</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['week'] = df.date.dt.isocalendar().week
df['weekday'] = df.date.dt.day_name().str[:3]
df.head
# Out:
# <bound method NDFrame.head of               date  number_of_strikes  center_point_geom  week weekday
# 0       2018-01-03                194      POINT(-75 27)     1     Wed
# 1       2018-01-03                 41    POINT(-78.4 29)     1     Wed
# 2       2018-01-03                 33    POINT(-73.9 27)     1     Wed
# 3       2018-01-03                 38    POINT(-73.8 27)     1     Wed
# 4       2018-01-03                 92      POINT(-79 28)     1     Wed
# ...            ...                ...                ...   ...     ...
# 3401007 2018-12-28                 30  POINT(-90.6 28.7)    52     Fri
# 3401008 2018-12-28                 30  POINT(-89.4 30.9)    52     Fri
# 3401009 2018-12-28                 30  POINT(-89.5 31.4)    52     Fri
# 3401010 2018-12-28                 30  POINT(-88.3 31.6)    52     Fri
# 3401011 2018-12-28                 30  POINT(-88.4 32.1)    52     Fri
#
# [3401012 rows x 5 columns]>

# %%
df[['weekday', 'number_of_strikes']].groupby(['weekday']).mean()
# Out:
#          number_of_strikes
# weekday
# Fri              13.349972
# Mon              13.152804
# Sat              12.732694
# Sun              12.324717
# Thu              13.240594
# Tue              13.813599
# Wed              13.224568

# %%
weekday_order = ['Mon','Tue', 'Wed', 'Thu','Fri','Sat','Sun']
df.head()
# Out:
#         date  number_of_strikes center_point_geom  week weekday
# 0 2018-01-03                194     POINT(-75 27)     1     Wed
# 1 2018-01-03                 41   POINT(-78.4 29)     1     Wed
# 2 2018-01-03                 33   POINT(-73.9 27)     1     Wed
# 3 2018-01-03                 38   POINT(-73.8 27)     1     Wed
# 4 2018-01-03                 92     POINT(-79 28)     1     Wed

# %%
g = sns.boxplot(data=df, 
            x='weekday',
            y='number_of_strikes', 
            order=weekday_order, 
            showfliers=False 
            );
g.set_title('Lightning distribution per weekday (2018)');

# %%
df2 = pd.read_csv('strikes_data2.csv')

# %%
union_df = pd.concat([df.drop(['weekday', 'week'], axis = 1), df2], ignore_index = True )

# %%
print(df.shape)
print(df2.shape)
print(union_df.shape)
print(df.shape[0] + df2.shape[0] == union_df.shape[0])
# Out:
# (3401012, 5)
# (7077991, 3)
# (10479003, 3)
# True

# %%
union_df['date'] = pd.to_datetime(union_df['date'])

# %%
union_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10479003 entries, 0 to 10479002
# Data columns (total 3 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   date               datetime64[ns]
#  1   number_of_strikes  int64
#  2   center_point_geom  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 239.8+ MB

# %%
union_df['year'] = union_df.date.dt.year
union_df['month'] = union_df.date.dt.month
union_df['month_txt'] = union_df.date.dt.month_name()
union_df.head()
# Out:
#         date  number_of_strikes center_point_geom  year  month month_txt
# 0 2018-01-03                194     POINT(-75 27)  2018      1   January
# 1 2018-01-03                 41   POINT(-78.4 29)  2018      1   January
# 2 2018-01-03                 33   POINT(-73.9 27)  2018      1   January
# 3 2018-01-03                 38   POINT(-73.8 27)  2018      1   January
# 4 2018-01-03                 92     POINT(-79 28)  2018      1   January

# %%
union_df[['year', 'number_of_strikes']].groupby(['year']).sum()
# Out:
#       number_of_strikes
# year
# 2016           41582229
# 2017           35095195
# 2018           44600989

# %%
lightning_by_month = union_df.groupby(['month_txt','year']).agg(
    number_of_strikes = pd.NamedAgg(column='number_of_strikes',aggfunc=sum)
    ).reset_index()

lightning_by_month.head()
# Out:
#   month_txt  year  number_of_strikes
# 0     April  2016            2636427
# 1     April  2017            3819075
# 2     April  2018            1524339
# 3    August  2016            7250442
# 4    August  2017            6021702

# %%
lightning_by_year = union_df.groupby(['year']).agg(
  year_strikes = pd.NamedAgg(column='number_of_strikes',aggfunc=sum)
).reset_index()

lightning_by_year.head()
# Out:
#    year  year_strikes
# 0  2016      41582229
# 1  2017      35095195
# 2  2018      44600989

# %%
percentage_lightning = lightning_by_month.merge(lightning_by_year,on='year')
percentage_lightning.head()
# Out:
#   month_txt  year  number_of_strikes  year_strikes
# 0     April  2016            2636427      41582229
# 1    August  2016            7250442      41582229
# 2  December  2016             316450      41582229
# 3  February  2016             312676      41582229
# 4   January  2016             313595      41582229

# %%
percentage_lightning['percentage_lightning_per_month'] = (percentage_lightning.number_of_strikes/
                                                          percentage_lightning.year_strikes * 100.0)
percentage_lightning.head(12)
# Out:
#     month_txt  year  number_of_strikes  year_strikes  \
# 0       April  2016            2636427      41582229
# 1      August  2016            7250442      41582229
# 2    December  2016             316450      41582229
# 3    February  2016             312676      41582229
# 4     January  2016             313595      41582229
# 5        July  2016           10661475      41582229
# 6        June  2016            6647930      41582229
# 7       March  2016            2057527      41582229
# 8         May  2016            5800500      41582229
# 9    November  2016             367853      41582229
# 10    October  2016            1285451      41582229
# 11  September  2016            3931903      41582229
#
#     percentage_lightning_per_month
# 0                         6.340273
# 1                        17.436396
# 2                         0.761022
# 3                         0.751946
# 4                         0.754156
# 5                        25.639499
# 6                        15.987431
# 7                         4.948092
# 8                        13.949469
# 9                         0.884640
# 10                        3.091347
# 11                        9.455729

# %%
plt.figure(figsize=(15,6));

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']

sns.barplot(
    data = percentage_lightning,
    x = 'month_txt',
    y = 'percentage_lightning_per_month',
    hue = 'year',
    order = month_order );
plt.xlabel("Month");
plt.ylabel("% of lightning strikes");
plt.title("% of lightning strikes each Month (2016-2018)");
